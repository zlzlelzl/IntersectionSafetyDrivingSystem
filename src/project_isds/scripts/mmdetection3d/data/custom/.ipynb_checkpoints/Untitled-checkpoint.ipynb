# %%
import os
lst = os.listdir('./velo')
lst.sort()
lst
for idx, l in enumerate(lst[1:]):
    os.rename(l, '{:0>6}.bin'.format(idx))
# Out:
# ['.ipynb_checkpoints',
#  '23-04-06-01-21-44-030031_Intensity.bin',
#  '23-04-06-01-21-44-536559_Intensity.bin',
#  '23-04-06-01-21-44-968588_Intensity.bin',
#  '23-04-06-01-21-45-334588_Intensity.bin',
#  '23-04-06-01-21-45-863602_Intensity.bin',
#  '23-04-06-01-21-46-310670_Intensity.bin',
#  '23-04-06-01-21-46-768677_Intensity.bin',
#  '23-04-06-01-21-47-223681_Intensity.bin',
#  '23-04-06-01-21-47-770963_Intensity.bin',
#  '23-04-06-01-21-48-271962_Intensity.bin',
#  '23-04-06-01-21-48-724961_Intensity.bin',
#  '23-04-06-01-21-49-076075_Intensity.bin',
#  '23-04-06-01-21-49-488803_Intensity.bin',
#  '23-04-06-01-21-49-778831_Intensity.bin',
#  '23-04-06-01-21-50-086776_Intensity.bin',
#  '23-04-06-01-21-50-385710_Intensity.bin',
#  '23-04-06-01-21-50-690709_Intensity.bin',
#  '23-04-06-01-21-51-127822_Intensity.bin',
#  '23-04-06-01-21-51-407932_Intensity.bin',
#  '23-04-06-01-21-51-696273_Intensity.bin',
#  '23-04-06-01-21-51-997273_Intensity.bin',
# ...

# %%
for idx, l in enumerate(lst[1:]):
    os.rename('velo/'+l, '{:0>6}.bin'.format(idx))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [7], line 2
#       1 for idx, l in enumerate(lst[1:]):
# ----> 2     os.rename(l, '{:0>6}.bin'.format(idx))
#
# FileNotFoundError: [Errno 2] No such file or directory: '23-04-06-01-21-44-030031_Intensity.bin' -> '000000.bin'

# %%
ls
# Out:
# 23-04-06-08-23-24-618552_Intensity.bin  23-04-06-08-23-54-600106_Intensity.bin
# 23-04-06-08-23-24-920425_Intensity.bin  23-04-06-08-23-54-885425_Intensity.bin
# 23-04-06-08-23-25-211592_Intensity.bin  23-04-06-08-23-55-179610_Intensity.bin
# 23-04-06-08-23-25-508782_Intensity.bin  23-04-06-08-23-55-467021_Intensity.bin
# 23-04-06-08-23-25-803379_Intensity.bin  23-04-06-08-23-55-789555_Intensity.bin
# 23-04-06-08-23-26-101856_Intensity.bin  23-04-06-08-23-56-090661_Intensity.bin
# 23-04-06-08-23-26-387266_Intensity.bin  23-04-06-08-23-56-375395_Intensity.bin
# 23-04-06-08-23-26-679385_Intensity.bin  23-04-06-08-23-56-666310_Intensity.bin
# 23-04-06-08-23-26-998186_Intensity.bin  23-04-06-08-23-56-953568_Intensity.bin
# 23-04-06-08-23-27-287244_Intensity.bin  23-04-06-08-23-57-238057_Intensity.bin
# 23-04-06-08-23-27-598803_Intensity.bin  23-04-06-08-23-57-555306_Intensity.bin
# 23-04-06-08-23-27-886414_Intensity.bin  23-04-06-08-23-57-854080_Intensity.bin
# ...
